# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuradha-1933/MachineLearing_Project/blob/main/end_to_end_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# for train test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 91   7.5  158.0
# 66   6.9   96.0
# 90   7.3   86.0
# 22   4.9  120.0
# 62   6.0  102.0
# ..   ...    ...
# 92   5.2  110.0
# 25   5.0   91.0
# 86   5.1  128.0
# 65   8.1  166.0
# 37   8.1  149.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 91    1
# 66    1
# 90    1
# 22    0
# 62    0
#      ..
# 92    0
# 25    0
# 86    0
# 65    1
# 37    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 36   5.7  140.0
# 64   7.0   64.0
# 84   5.7  169.0
# 16   5.2  224.0
# 80   4.9  196.0
# 39   4.6  146.0
# 58   8.0   79.0
# 59   4.8  112.0
# 77   7.3   50.0
# 0    6.8  123.0

# %%
y_test
# Out:
# 36    0
# 64    1
# 84    0
# 16    0
# 80    0
# 39    0
# 58    1
# 59    0
# 77    1
# 0     1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.32593948,  0.93010765],
#        [ 0.79907611, -0.709703  ],
#        [ 1.15031836, -0.97418858],
#        [-0.95713512, -0.07493758],
#        [ 0.00878106, -0.55101164],
#        [ 0.44783386,  0.18954801],
#        [ 1.32593948, -1.63540256],
#        [-0.16684007,  1.14169612],
#        [ 0.71126555,  0.48048215],
#        [ 1.58937117, -0.23362894],
#        [ 0.3600233 ,  0.48048215],
#        [-1.13275625, -0.04848902],
#        [-1.04494568,  1.2210418 ],
#        [-1.04494568,  0.48048215],
#        [ 0.44783386, -2.27016797],
#        [-0.69370344,  1.00945333],
#        [-0.16684007,  0.50693071],
#        [-0.86932456, -0.1278347 ],
#        [ 1.15031836,  0.37468792],
#        [ 0.62345499,  1.56487307],
#        [-1.13275625, -1.87343959],
#        [-1.39618793,  0.69207062],
#        [-0.60589288, -0.04848902],
#        [ 0.09659162,  0.87721054],
#        [ 1.23812892,  0.24244512],
#        [-0.95713512,  0.85076198],
#        [ 0.09659162,  0.24244512],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.25465063,  0.45403359],
#        [ 0.88688667, -1.55605688],
#        [-0.25465063,  1.2210418 ],
#        [-0.69370344,  2.67571254],
#        [-0.95713512,  1.93515289],
#        [-1.22056681,  0.61272495],
#        [ 1.76499229, -1.1593285 ],
#        [-1.04494568, -0.28652605],
#        [ 1.15031836, -1.9263367 ],
#        [ 0.71126555,  0.00440809]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 0, 0, 0, 0, 1, 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
#clf=classifier
plot_decision_regions(x_train, y_train.values, clf=clf, legend=10)
# Out:
# <Axes: >

# %%
#In python,everthing is an object, pickel convert object into file and we use this file in any environment
import pickle

# %%
#convert a file in binary form
pickle.dump(clf, open('model2.pkl', 'wb'))
